# %%
import pandas as pd

df = pd.read_csv ("D:/material estudio/preciossurtidor2016.csv", sep = ",")

# %%
#primeros 5 registros
df.head()
# Out:
#   indice_tiempo  idempresa           cuit               empresa  \
# 0       2022-10       1376  33-64337382-9  10 DE SETIEMBRE S.A.
# 1       2022-10       1376  33-64337382-9  10 DE SETIEMBRE S.A.
# 2       2022-10       1376  33-64337382-9  10 DE SETIEMBRE S.A.
# 3       2022-10       1376  33-64337382-9  10 DE SETIEMBRE S.A.
# 4       2022-09       1376  33-64337382-9  10 DE SETIEMBRE S.A.
#
#          direccion          localidad     provincia    region  idproducto  \
# 0  Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES  PAMPEANA          19
# 1  Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES  PAMPEANA          19
# 2  Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES  PAMPEANA          21
# 3  Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES  PAMPEANA          21
# 4  Av. Mosconi 299  LOMAS DEL MIRADOR  BUENOS AIRES  PAMPEANA           6
#
#           producto  idtipohorario tipohorario  precio       fecha_vigencia  \
# ...

# %%
#ultimos 5 registros
df.tail()
# Out:
#       indice_tiempo  idempresa           cuit      empresa        direccion  \
# 37029       2023-08       4097  30-70795820-7  ZUSICO S.A.  TALCAHUANO 1198
# 37030       2023-08       4097  30-70795820-7  ZUSICO S.A.  TALCAHUANO 1198
# 37031       2023-08       4097  30-70795820-7  ZUSICO S.A.  TALCAHUANO 1198
# 37032       2023-08       4097  30-70795820-7  ZUSICO S.A.  TALCAHUANO 1198
# 37033       2023-08       4097  30-70795820-7  ZUSICO S.A.  TALCAHUANO 1198
#
#            localidad     provincia    region  idproducto  \
# 37029  MAR DEL PLATA  BUENOS AIRES  PAMPEANA           6
# 37030  MAR DEL PLATA  BUENOS AIRES  PAMPEANA           3
# 37031  MAR DEL PLATA  BUENOS AIRES  PAMPEANA           3
# 37032  MAR DEL PLATA  BUENOS AIRES  PAMPEANA           2
# 37033  MAR DEL PLATA  BUENOS AIRES  PAMPEANA           2
#
#                                producto  idtipohorario tipohorario  precio  \
# 37029                               GNC              3    Nocturno   179.0
# ...

# %%
#dimensiones del dset
print(df.shape)
# Out:
# (37034, 19)

# %%
#obtener totalidad registros x columnas.analizar valores missings
df.count()
# Out:
# indice_tiempo       37034
# idempresa           37034
# cuit                37034
# empresa             37034
# direccion           37034
# localidad           37034
# provincia           37034
# region              30375
# idproducto          37034
# producto            37034
# idtipohorario       37034
# tipohorario         37034
# precio              37034
# fecha_vigencia      37034
# idempresabandera    37034
# empresabandera      37034
# latitud             37002
# longitud            37002
# geojson             37002
# dtype: int64

# %%
#info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37034 entries, 0 to 37033
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   indice_tiempo     37034 non-null  object
#  1   idempresa         37034 non-null  int64
#  2   cuit              37034 non-null  object
#  3   empresa           37034 non-null  object
#  4   direccion         37034 non-null  object
#  5   localidad         37034 non-null  object
#  6   provincia         37034 non-null  object
#  7   region            30375 non-null  object
#  8   idproducto        37034 non-null  int64
#  9   producto          37034 non-null  object
#  10  idtipohorario     37034 non-null  int64
#  11  tipohorario       37034 non-null  object
#  12  precio            37034 non-null  float64
#  13  fecha_vigencia    37034 non-null  object
#  14  idempresabandera  37034 non-null  int64
#  15  empresabandera    37034 non-null  object
# ...

# %%
df.dtypes
# Out:
# indice_tiempo        object
# idempresa             int64
# cuit                 object
# empresa              object
# direccion            object
# localidad            object
# provincia            object
# region               object
# idproducto            int64
# producto             object
# idtipohorario         int64
# tipohorario          object
# precio              float64
# fecha_vigencia       object
# idempresabandera      int64
# empresabandera       object
# latitud             float64
# longitud            float64
# geojson              object
# dtype: object

# %%
#verificar la estructura del dataset
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#listar nombres de las columnas del dataset
print(df.columns)
# Out:
# Index(['indice_tiempo', 'idempresa', 'cuit', 'empresa', 'direccion',
#        'localidad', 'provincia', 'region', 'idproducto', 'producto',
#        'idtipohorario', 'tipohorario', 'precio', 'fecha_vigencia',
#        'idempresabandera', 'empresabandera', 'latitud', 'longitud', 'geojson'],
#       dtype='object')

# %%
#eliminar columnas 'idempresa' , 'cuit'
columns_to_drop = ['idempresa' , 'cuit']
df.drop (columns_to_drop, axis = "columns", inplace = True) # inplace = true sirve para sobreescribir el objeto
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 3
#       1 #eliminar columnas 'idempresa' , 'cuit'
#       2 columns_to_drop = ['idempresa' , 'cuit']
# ----> 3 df.drop (columns_to_drop, axis = "columns", inplace = True)
#
# File D:\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File D:\anaconda3\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
print (df.shape)
# Out:
# (37034, 17)

# %%
#completar valores missings
df.fillna({'latitud': 0}, inplace = True)

# %%
df.count()
# Out:
# indice_tiempo       37034
# empresa             37034
# direccion           37034
# localidad           37034
# provincia           37034
# region              30375
# idproducto          37034
# producto            37034
# idtipohorario       37034
# tipohorario         37034
# precio              37034
# fecha_vigencia      37034
# idempresabandera    37034
# empresabandera      37034
# latitud             37034
# longitud            37002
# geojson             37002
# dtype: int64
